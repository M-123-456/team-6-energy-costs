# %% [markdown]
# ## Linear Regression

# %%
from darts import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt
from darts.metrics import mape
import numpy as np
import datetime as dt
from darts.dataprocessing.transformers import Scaler
from darts.models import RegressionModel
from darts import concatenate
from darts.utils.timeseries_generation import datetime_attribute_timeseries as dt_attr
from sklearn.linear_model import BayesianRidge

# %%
# Read a pandas DataFrame
df = pd.read_csv('../../../data/prepared/df_energy_climate_2020.csv')

# %%
df.dropna(inplace=True)

# %%
series_price = TimeSeries.from_dataframe(
    df, 
    time_col="datetime",
    value_cols=["energy_price"]
)

# %%
splitting_point = (int(len(series_price)*0.20))

# Set aside the second half of series as a validation series
train_price, val_price = series_price[:-splitting_point], series_price[-splitting_point:]

# %%
model = RegressionModel(
    lags=[-7000,-672]
)

# %%
model.fit(train_price)

# %%
pred_price = model.predict(
    series=train_price, n=len(val_price)
)

# %%
series_price.plot(label='actual price')
pred_price.plot(label='forecast price')

# %%
print(f'Mape = {mape(series_price, pred_price, inter_reduction=np.mean):.2f}%')
# Out:
# Mape = 1518.14%

# %%
backtest = model.historical_forecasts(
    series_price,
    start=0.8,
    forecast_horizon=168,
    stride=5,
    overlap_end=False,
    verbose=True
)
# Out:
#   0%|          | 0/319 [00:00<?, ?it/s]

# %%
print(f'MAPE = {mape(backtest, val_price):.2f}%')
# Out:
# MAPE = 104.46%

# %%
series_wind = TimeSeries.from_dataframe(
    df, 
    time_col="datetime",
    value_cols=["wind_speed"]
)
series_not_renewable = TimeSeries.from_dataframe(
    df,
    time_col='datetime',
    value_cols=['not_renewable']
)

# %%
scaler = Scaler()

# %%
train_price_scaled, not_renewable_scaled, wind_scaled = scaler.fit_transform([
    train_price, 
    series_not_renewable, 
    series_wind
])

# %%
pd.notnull(not_renewable_scaled)
# Out:
# True

# %%
pd.notnull(wind_scaled)
# Out:
# True

# %%
time_covariates = concatenate(
    [
        dt_attr(series_price.time_index, 'month', dtype=np.float32),
        dt_attr(series_price.time_index, 'hour', dtype=np.float32),
        dt_attr(series_price.time_index, 'weekday', dtype=np.float32)
    ],
    axis='component'
)

# %%
plt.figure(figsize=(15, 8))
time_covariates.plot()

# %%
pd.notnull(time_covariates)
# Out:
# True

# %%
time_covariates
# Out:
# <TimeSeries (DataArray) (datetime: 8784, component: 3, sample: 1)>
# array([[[ 1.],
#         [ 0.],
#         [ 2.]],
#
#        [[ 1.],
#         [ 1.],
#         [ 2.]],
#
#        [[ 1.],
#         [ 2.],
#         [ 2.]],
#
#        ...,
#
#        [[12.],
#         [21.],
#         [ 3.]],
#
#        [[12.],
#         [22.],
#         [ 3.]],
#
#        [[12.],
#         [23.],
#         [ 3.]]], dtype=float32)
# Coordinates:
#   * datetime   (datetime) datetime64[ns] 2020-01-01 ... 2020-12-31T23:00:00
#   * component  (component) object 'month' 'hour' 'weekday'
# Dimensions without coordinates: sample
# Attributes:
#     static_covariates:  None
#     hierarchy:          None

# %%
model_covariants = RegressionModel(
    lags=[-7000,-168],
    lags_future_covariates=[-168, 0],
)

# %%
model_covariants.fit(
    train_price_scaled,
    future_covariates=[not_renewable_scaled, wind_scaled, time_covariates]
)

# %%
pred_price = model_covariants.predict(
    series=train_price_scaled,
    future_covariates=[not_renewable_scaled, wind_scaled, time_covariates],
    n=len(val_price)
)

pred_price = scaler.inverse_transform(pred_price)

# %%
series_price.plot(label='actual price')
pred_price.plot(label='forecast price')

# %%
mape(series_price, pred_price, inter_reduction=np.mean)
# Out:
# 247.86673025559512

# %%
backtest_covariants = model_covariants.historical_forecasts(
    series_price,
    start=0.98,
    future_covariates=time_covariates,
    forecast_horizon=168,
    verbose=True
)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
#
# Intel MKL ERROR: Parameter 4 was incorrect on entry to DLASCL.
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /tmp/ipykernel_16541/2381555820.py in <module>
# ----> 1 backtest_covariants = model_covariants.historical_forecasts(
#       2     series_price,
#       3     start=0.98,
#       4     future_covariates=time_covariates,
#       5     forecast_horizon=168,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/utils/utils.py in sanitized_method(self, *args, **kwargs)
#     177
#     178                 getattr(self, sanity_check_method)(*only_args.values(), **only_kwargs)
# --> 179             return method_to_sanitize(self, *only_args.values(), **only_kwargs)
#     180
#     181         return sanitized_method
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py in historical_forecasts(self, series, past_covariates, future_covariates, num_samples, train_length, start, forecast_horizon, stride, retrain, overlap_end, last_points_only, verbose)
#     863                     # avoid fitting the same model multiple times
#     864                     model = self.untrained_model()
# --> 865                     model._fit_wrapper(
#     866                         series=train_series,
#     867                         past_covariates=past_covariates_,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py in _fit_wrapper(self, series, past_covariates, future_covariates)
#    1815         future_covariates: Optional[TimeSeries],
#    1816     ):
# -> 1817         self.fit(
#    1818             series=series,
#    1819             past_covariates=past_covariates if self.supports_past_covariates else None,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py in fit(self, series, past_covariates, future_covariates, max_samples_per_ts, n_jobs_multioutput_wrapper, **kwargs)
#     480         )
#     481
# --> 482         self._fit_model(
#     483             series, past_covariates, future_covariates, max_samples_per_ts, **kwargs
#     484         )
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py in _fit_model(self, target_series, past_covariates, future_covariates, max_samples_per_ts, **kwargs)
#     369         if len(training_labels.shape) == 2 and training_labels.shape[1] == 1:
#     370             training_labels = training_labels.ravel()
# --> 371         self.model.fit(training_samples, training_labels, **kwargs)
#     372
#     373     def fit(
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     716                 self._residues = np.vstack([out[3] for out in outs])
#     717         else:
# --> 718             self.coef_, self._residues, self.rank_, self.singular_ = linalg.lstsq(X, y)
#     719             self.coef_ = self.coef_.T
#     720
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_basic.py in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1198                                                cond, False, False)
#    1199         if info > 0:
# -> 1200             raise LinAlgError("SVD did not converge in Linear Least Squares")
#    1201         if info < 0:
#    1202             raise ValueError('illegal value in %d-th argument of internal %s'
#
# LinAlgError: SVD did not converge in Linear Least Squares
