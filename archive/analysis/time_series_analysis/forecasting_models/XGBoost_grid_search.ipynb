# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('../../../data/prepared/df_energy_climate_2020.csv')
df = df.set_index('datetime')
df.index = pd.to_datetime(df.index)

# %%
df.head(3)
# Out:
#                      wind_speed  solar_radiation  temperature  nuclear_power  \
# datetime
# 2020-01-01 00:00:00         2.4                0         -0.1     8088.21750
# 2020-01-01 01:00:00         2.4                0         -0.5     8081.15875
# 2020-01-01 02:00:00         2.5                0         -0.7     8071.44750
#
#                      not_renewable    renewable  energy_price  hour  \
# datetime
# 2020-01-01 00:00:00    29512.74850  14541.30200         38.60   0.0
# 2020-01-01 01:00:00    29178.66275  14949.45575         36.55   1.0
# 2020-01-01 02:00:00    29414.36225  15077.92500         32.32   2.0
#
#                      dayofweek  month        date
# datetime
# 2020-01-01 00:00:00        2.0    1.0  2020-01-01
# 2020-01-01 01:00:00        2.0    1.0  2020-01-01
# 2020-01-01 02:00:00        2.0    1.0  2020-01-01

# %%
df_energy = df[['energy_price', 'hour', 'month', 'dayofweek', 'date', ]].copy()

# %%
df_energy.plot(
    y='energy_price', 
    style='.', figsize=(15, 5), 
    color=color_pal[0],  # type: ignore
    title='Energy price'
)
plt.show()

# %% [markdown]
# ## Train / Test Split

# %%
train = df_energy.loc[df_energy.index < '2020-11-01']
test = df_energy.loc[df_energy.index >= '2020-11-01']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, y='energy_price', label='Training Set')
test.plot(ax=ax, y='energy_price', label='Test Set')
ax.axvline('2020-11-01', color='black', ls='--')
plt.show()

# %% [markdown]
# ## Create our Model

# %%
FEATURES = ['hour', 'month', 'dayofweek']
TARGET = 'energy_price'

# %%
X_train=train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor()

# %%
# make a dictionary of hyperparameter values to search
search_space = {
    'n_estimators': [100, 500, 1000],
    'max_depth': [3, 6, 9],
    'gamma': [0.01, 0.1],
    'learning_rate': [0.001, 0.01, 0.1],
}

GS = GridSearchCV(estimator = reg,
                  param_grid = search_space,
                  scoring=['r2', 'neg_root_mean_squared_error'],
                  refit = 'r2',
                  cv = 5,
                  verbose=4
)

# %%
GS.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-30.135) r2: (test=-2.734) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-22.766) r2: (test=-1.176) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-23.351) r2: (test=-2.219) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-31.309) r2: (test=-4.268) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-39.017) r2: (test=-4.237) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-25.050) r2: (test=-1.580) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.782) r2: (test=-0.328) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-16.595) r2: (test=-0.626) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-21.568) r2: (test=-1.500) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-30.428) r2: (test=-2.185) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-20.817) r2: (test=-0.782) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.353) r2: (test=0.010) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-12.262) r2: (test=0.112) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.042) r2: (test=-0.216) total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-24.101) r2: (test=-0.998) total time=   0.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-29.947) r2: (test=-2.687) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-22.941) r2: (test=-1.210) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-23.276) r2: (test=-2.199) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-30.899) r2: (test=-4.131) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-38.765) r2: (test=-4.169) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-24.228) r2: (test=-1.413) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-18.020) r2: (test=-0.363) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.174) r2: (test=-0.741) total time=   0.9s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-20.823) r2: (test=-1.330) total time=   1.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-29.246) r2: (test=-1.942) total time=   0.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-19.985) r2: (test=-0.642) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-15.131) r2: (test=0.039) total time=   1.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-13.232) r2: (test=-0.034) total time=   1.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-13.992) r2: (test=-0.052) total time=   1.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-22.281) r2: (test=-0.708) total time=   1.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-29.952) r2: (test=-2.689) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-22.860) r2: (test=-1.194) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-23.451) r2: (test=-2.247) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-31.191) r2: (test=-4.228) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-38.750) r2: (test=-4.165) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-24.101) r2: (test=-1.388) total time=   1.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.824) r2: (test=-0.334) total time=   1.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-18.008) r2: (test=-0.915) total time=   1.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-20.561) r2: (test=-1.272) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-29.252) r2: (test=-1.944) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-19.893) r2: (test=-0.627) total time=   2.8s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.932) r2: (test=0.064) total time=   2.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.449) r2: (test=-0.233) total time=   2.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-13.923) r2: (test=-0.042) total time=   2.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-22.188) r2: (test=-0.694) total time=   2.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-20.786) r2: (test=-0.776) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.328) r2: (test=0.014) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-12.235) r2: (test=0.116) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-14.991) r2: (test=-0.208) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-24.049) r2: (test=-0.989) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-15.603) r2: (test=-0.001) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-14.009) r2: (test=0.176) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-10.297) r2: (test=0.374) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-11.010) r2: (test=0.349) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-14.533) r2: (test=0.273) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.399) r2: (test=0.025) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-13.521) r2: (test=0.232) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-12.669) r2: (test=0.052) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-11.372) r2: (test=0.305) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-14.093) r2: (test=0.317) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-19.950) r2: (test=-0.636) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.114) r2: (test=0.041) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.199) r2: (test=-0.029) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.958) r2: (test=-0.047) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-22.233) r2: (test=-0.700) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-15.424) r2: (test=0.022) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-13.799) r2: (test=0.201) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.724) r2: (test=0.044) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.397) r2: (test=0.174) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.074) r2: (test=0.319) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-15.442) r2: (test=0.020) total time=   1.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-13.952) r2: (test=0.183) total time=   1.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.352) r2: (test=-0.216) total time=   1.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-12.697) r2: (test=0.134) total time=   1.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.071) r2: (test=0.319) total time=   1.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-19.869) r2: (test=-0.623) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.918) r2: (test=0.065) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.409) r2: (test=-0.226) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-13.885) r2: (test=-0.036) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-22.141) r2: (test=-0.686) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-15.551) r2: (test=0.006) total time=   1.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.106) r2: (test=0.165) total time=   1.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-13.944) r2: (test=-0.148) total time=   1.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-13.938) r2: (test=-0.044) total time=   1.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.216) r2: (test=0.305) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-15.545) r2: (test=0.006) total time=   2.0s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.222) r2: (test=0.151) total time=   2.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.334) r2: (test=-0.213) total time=   2.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.121) r2: (test=-0.072) total time=   2.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.158) r2: (test=0.310) total time=   2.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.303) r2: (test=0.037) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-13.438) r2: (test=0.242) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-12.585) r2: (test=0.065) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-11.491) r2: (test=0.290) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-14.139) r2: (test=0.312) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-15.256) r2: (test=0.043) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.806) r2: (test=0.200) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-15.981) r2: (test=-0.508) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.101) r2: (test=0.213) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.889) r2: (test=0.336) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.343) r2: (test=0.032) total time=   0.8s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-14.049) r2: (test=0.171) total time=   1.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-16.246) r2: (test=-0.558) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-12.382) r2: (test=0.176) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-13.978) r2: (test=0.328) total time=   0.8s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.414) r2: (test=0.023) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.927) r2: (test=0.186) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.999) r2: (test=-0.157) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-12.741) r2: (test=0.128) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-14.024) r2: (test=0.323) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-15.542) r2: (test=0.007) total time=   0.6s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.174) r2: (test=0.156) total time=   0.6s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.727) r2: (test=-0.280) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.889) r2: (test=0.107) total time=   0.7s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.153) r2: (test=0.311) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-15.550) r2: (test=0.006) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.185) r2: (test=0.155) total time=   1.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.766) r2: (test=-0.287) total time=   1.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-12.914) r2: (test=0.104) total time=   1.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.158) r2: (test=0.310) total time=   1.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.542) r2: (test=0.007) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.220) r2: (test=0.151) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.237) r2: (test=-0.197) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.330) r2: (test=-0.104) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.159) r2: (test=0.310) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-15.550) r2: (test=0.006) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.241) r2: (test=0.148) total time=   1.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.271) r2: (test=-0.203) total time=   1.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.335) r2: (test=-0.104) total time=   1.0s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.159) r2: (test=0.310) total time=   1.0s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-15.550) r2: (test=0.006) total time=   1.9s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.241) r2: (test=0.148) total time=   2.0s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.271) r2: (test=-0.203) total time=   2.0s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.335) r2: (test=-0.104) total time=   2.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.159) r2: (test=0.310) total time=   2.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-30.135) r2: (test=-2.734) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-22.766) r2: (test=-1.176) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-23.351) r2: (test=-2.219) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-31.309) r2: (test=-4.268) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-39.017) r2: (test=-4.237) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-25.050) r2: (test=-1.580) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.782) r2: (test=-0.328) total time=   0.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-16.595) r2: (test=-0.626) total time=   0.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-21.568) r2: (test=-1.500) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-30.428) r2: (test=-2.185) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-20.817) r2: (test=-0.782) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.353) r2: (test=0.010) total time=   0.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-12.262) r2: (test=0.112) total time=   0.7s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.042) r2: (test=-0.216) total time=   0.6s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-24.101) r2: (test=-0.998) total time=   0.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-29.947) r2: (test=-2.687) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-22.941) r2: (test=-1.210) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-23.276) r2: (test=-2.199) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-30.899) r2: (test=-4.131) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-38.765) r2: (test=-4.169) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-24.228) r2: (test=-1.413) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-18.020) r2: (test=-0.363) total time=   0.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.174) r2: (test=-0.741) total time=   0.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-20.823) r2: (test=-1.330) total time=   0.6s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-29.246) r2: (test=-1.942) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-19.984) r2: (test=-0.642) total time=   1.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-15.131) r2: (test=0.039) total time=   1.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-13.232) r2: (test=-0.034) total time=   1.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-13.993) r2: (test=-0.052) total time=   1.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-22.281) r2: (test=-0.708) total time=   1.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-29.952) r2: (test=-2.689) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-22.860) r2: (test=-1.194) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-23.451) r2: (test=-2.247) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-31.191) r2: (test=-4.228) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-38.750) r2: (test=-4.165) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-24.101) r2: (test=-1.388) total time=   1.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.824) r2: (test=-0.334) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-18.008) r2: (test=-0.915) total time=   0.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-20.561) r2: (test=-1.272) total time=   0.9s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-29.252) r2: (test=-1.944) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-19.893) r2: (test=-0.627) total time=   1.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.932) r2: (test=0.064) total time=   1.7s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.448) r2: (test=-0.232) total time=   1.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-13.922) r2: (test=-0.042) total time=   2.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-22.188) r2: (test=-0.694) total time=   1.9s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-20.786) r2: (test=-0.776) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.328) r2: (test=0.014) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-12.235) r2: (test=0.116) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-14.991) r2: (test=-0.208) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-24.049) r2: (test=-0.989) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-15.603) r2: (test=-0.001) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-14.009) r2: (test=0.176) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-10.297) r2: (test=0.374) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-11.010) r2: (test=0.349) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-14.533) r2: (test=0.273) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.399) r2: (test=0.025) total time=   1.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-13.521) r2: (test=0.232) total time=   0.7s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-12.669) r2: (test=0.052) total time=   0.7s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-11.372) r2: (test=0.305) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-14.093) r2: (test=0.317) total time=   0.6s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-19.950) r2: (test=-0.636) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.114) r2: (test=0.041) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.199) r2: (test=-0.029) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.958) r2: (test=-0.047) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-22.233) r2: (test=-0.700) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-15.427) r2: (test=0.021) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-13.776) r2: (test=0.203) total time=   0.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.728) r2: (test=0.043) total time=   0.7s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.399) r2: (test=0.174) total time=   0.7s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.078) r2: (test=0.318) total time=   0.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-15.454) r2: (test=0.018) total time=   1.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-13.917) r2: (test=0.187) total time=   1.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.220) r2: (test=-0.194) total time=   1.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-12.694) r2: (test=0.134) total time=   1.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.067) r2: (test=0.319) total time=   1.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-19.869) r2: (test=-0.623) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.918) r2: (test=0.065) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.408) r2: (test=-0.226) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-13.885) r2: (test=-0.036) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-22.141) r2: (test=-0.686) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-15.551) r2: (test=0.006) total time=   1.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.104) r2: (test=0.165) total time=   1.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-13.987) r2: (test=-0.155) total time=   1.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-13.946) r2: (test=-0.045) total time=   1.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.205) r2: (test=0.306) total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-15.543) r2: (test=0.007) total time=   2.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.246) r2: (test=0.148) total time=   2.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.270) r2: (test=-0.202) total time=   2.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.135) r2: (test=-0.074) total time=   2.6s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.153) r2: (test=0.311) total time=   2.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.303) r2: (test=0.037) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-13.438) r2: (test=0.242) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-12.585) r2: (test=0.065) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-11.491) r2: (test=0.290) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-14.139) r2: (test=0.312) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-15.256) r2: (test=0.043) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.806) r2: (test=0.200) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-15.981) r2: (test=-0.508) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.101) r2: (test=0.213) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.889) r2: (test=0.336) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-15.343) r2: (test=0.032) total time=   0.7s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-14.049) r2: (test=0.171) total time=   0.7s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-16.246) r2: (test=-0.558) total time=   0.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-12.382) r2: (test=0.176) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=1000; neg_root_mean_squared_error: (test=-13.978) r2: (test=0.328) total time=   0.8s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.426) r2: (test=0.022) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.911) r2: (test=0.187) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-13.815) r2: (test=-0.127) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-12.742) r2: (test=0.127) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-14.084) r2: (test=0.318) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-15.541) r2: (test=0.007) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.103) r2: (test=0.165) total time=   0.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.621) r2: (test=-0.262) total time=   0.9s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.870) r2: (test=0.110) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-14.152) r2: (test=0.311) total time=   0.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-15.545) r2: (test=0.006) total time=   1.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.113) r2: (test=0.164) total time=   1.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.644) r2: (test=-0.266) total time=   1.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-12.877) r2: (test=0.109) total time=   1.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=1000; neg_root_mean_squared_error: (test=-14.154) r2: (test=0.311) total time=   1.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.539) r2: (test=0.007) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.225) r2: (test=0.150) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.263) r2: (test=-0.201) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.314) r2: (test=-0.101) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.157) r2: (test=0.311) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-15.546) r2: (test=0.006) total time=   1.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.249) r2: (test=0.147) total time=   1.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.294) r2: (test=-0.206) total time=   1.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.312) r2: (test=-0.101) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-14.157) r2: (test=0.311) total time=   1.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-15.546) r2: (test=0.006) total time=   2.0s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.249) r2: (test=0.147) total time=   2.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.294) r2: (test=-0.206) total time=   2.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.312) r2: (test=-0.101) total time=   1.8s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=1000; neg_root_mean_squared_error: (test=-14.157) r2: (test=0.311) total time=   2.2s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 500, 1000]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
print(GS.best_estimator_)
print(GS.best_params_)
print(GS.best_score_)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.01, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# {'gamma': 0.01, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# 0.23417390065680205

# %% [markdown]
# ## Forecast on Test

# %%
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:24.17344	validation_1-rmse:34.44571
# [99]	validation_0-rmse:9.21506	validation_1-rmse:18.00511
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test['prediction'] = reg.predict(X_test)
# Out:
# /var/folders/cz/cwy65nds1w7_vfh7mtxwrks40000gn/T/ipykernel_5753/2903689382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = reg.predict(X_test)

# %%
df_energy = df_energy.merge(
    test[['prediction']], 
    how='left', left_index=True, 
    right_index=True
)

# %%
ax = df_energy[['energy_price']].plot(figsize=(15, 5))
df_energy['prediction'].plot(ax=ax, style='.')
plt.legend(['Truthe Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
df_energy.loc[(df_energy.index > '2020-11-02') & (df_energy.index < '2020-11-09')].plot(figsize=(15,5), title='Week Of Data')
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['energy_price'], test['prediction']))
print(f'RMSE Score on Test set: {score:.2f}')
# Out:
# RMSE Score on Test set: 18.01

# %%
reg_hyper = xgb.XGBRegressor(
                            n_estimators=500,
                            base_score=0.5,
                            booster='gbtree',
                            objective='reg:linear',
                            max_depth=3,
                            gamma=0.01,
                            learning_rate=0.01,
                            early_stopping_rounds=50,
)

# %%
reg_hyper.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [22:04:46] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_b2k4a2hea3/croot/xgboost-split_1675457783214/work/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:32.08544	validation_1-rmse:44.30482
# [100]	validation_0-rmse:16.81730	validation_1-rmse:24.26773
# [200]	validation_0-rmse:12.79622	validation_1-rmse:19.14741
# [300]	validation_0-rmse:11.73909	validation_1-rmse:17.71603
# [400]	validation_0-rmse:11.28049	validation_1-rmse:17.29359
# [499]	validation_0-rmse:11.01709	validation_1-rmse:17.18915
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.01, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
test['prediction_with_hyperparams'] = reg.predict(X_test)
# Out:
# /var/folders/cz/cwy65nds1w7_vfh7mtxwrks40000gn/T/ipykernel_5753/3257391019.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction_with_hyperparams'] = reg.predict(X_test)

# %%
df_energy = df_energy.merge(
    test[['prediction_with_hyperparams']], 
    how='left', left_index=True, 
    right_index=True
)

# %%
df_energy
# Out:
#                      energy_price  hour  month  dayofweek        date  \
# datetime
# 2020-01-01 00:00:00         38.60   0.0    1.0        2.0  2020-01-01
# 2020-01-01 01:00:00         36.55   1.0    1.0        2.0  2020-01-01
# 2020-01-01 02:00:00         32.32   2.0    1.0        2.0  2020-01-01
# 2020-01-01 03:00:00         30.85   3.0    1.0        2.0  2020-01-01
# 2020-01-01 04:00:00         30.14   4.0    1.0        2.0  2020-01-01
# ...                           ...   ...    ...        ...         ...
# 2020-12-31 19:00:00         56.70  19.0   12.0        3.0  2020-12-31
# 2020-12-31 20:00:00         52.44  20.0   12.0        3.0  2020-12-31
# 2020-12-31 21:00:00         51.86  21.0   12.0        3.0  2020-12-31
# 2020-12-31 22:00:00         52.26  22.0   12.0        3.0  2020-12-31
# 2020-12-31 23:00:00         50.87  23.0   12.0        3.0  2020-12-31
#
#                      prediction  prediction_with_hyperparams
# datetime
# 2020-01-01 00:00:00         NaN                          NaN
# 2020-01-01 01:00:00         NaN                          NaN
# 2020-01-01 02:00:00         NaN                          NaN
# 2020-01-01 03:00:00         NaN                          NaN
# 2020-01-01 04:00:00         NaN                          NaN
# ...                         ...                          ...
# 2020-12-31 19:00:00   36.305603                    36.305603
# 2020-12-31 20:00:00   33.134274                    33.134274
# 2020-12-31 21:00:00   28.676767                    28.676767
# 2020-12-31 22:00:00   27.270815                    27.270815
# 2020-12-31 23:00:00   27.875845                    27.875845
#
# [8784 rows x 7 columns]

# %%
ax = df_energy[['energy_price']].plot(figsize=(15, 5))
df_energy['prediction_with_hyperparams'].plot(ax=ax, style='.')
plt.legend(['Truthe Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
df_energy.loc[(df_energy.index > '2020-11-02') & (df_energy.index < '2020-11-09')].plot(figsize=(15,5), title='Week Of Data')
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['energy_price'], test['prediction_with_hyperparams']))
print(f'RMSE Score on Test set: {score:.2f}')
# Out:
# RMSE Score on Test set: 18.01
