# %% [markdown]
# ## AutoARIMA
#
# - Univariate
# - The auto-ARIMA process seeks to identify the most optimal parameters for an ARIMA model, setting on a single fitted ARIMA model. Accept only univariate dataset.
# - AR(auto regression model) MA(moving average model) -> ARMA
# - ARIMA: Auto Regressive Integrated Moving Average

# %%
from darts import TimeSeries
from darts.models import StatsForecastAutoARIMA
from darts.utils.statistics import plot_hist
from darts.metrics import mape
import pandas as pd
import numpy as np
from darts import concatenate
from darts.utils.timeseries_generation import datetime_attribute_timeseries as dt_attr
from darts.dataprocessing.transformers import Scaler

# %%
df = pd.read_csv('../../../data/prepared/df_energy_climate_2020.csv')

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df['day_of_week'] = df['datetime'].dt.dayofweek

# %%
series_price = TimeSeries.from_dataframe(df, 
                                   time_col="datetime",
                                   value_cols=["energy_price"])
series_wind = TimeSeries.from_dataframe(df, 
                                   time_col="datetime",
                                   value_cols=["wind_speed"])

# %%
encoders = {
    "datetime_attribute": {"future": ["time", "day_of_week", 'month']},
    'transformer': Scaler()
}

# %%
splitting_point = (int(len(series_price)*0.20))
train_price, val_price = series_price[:-splitting_point], series_price[-splitting_point:]

# %%
model = StatsForecastAutoARIMA(
    add_encoders=encoders,
)

# %%
model.fit(train_price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15588/3412114628.py in <module>
# ----> 1 model.fit(train_price)
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py in fit(self, series, future_covariates)
#    1877         self.encoders = self.initialize_encoders()
#    1878         if self.encoders.encoding_available:
# -> 1879             _, future_covariates = self.generate_fit_encodings(
#    1880                 series=series,
#    1881                 past_covariates=None,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py in generate_fit_encodings(self, series, past_covariates, future_covariates)
#    1426             logger=logger,
#    1427         )
# -> 1428         return self.encoders.encode_train(
#    1429             target=series,
#    1430             past_covariates=past_covariates,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/dataprocessing/encoders/encoders.py in encode_train(self, target, past_covariates, future_covariates, encode_past, encode_future)
#     936
#     937             self._fit_called = True
# --> 938         past_covariates, future_covariates = self._launch_encoder(
#     939             target=target,
#     940             past_covariates=past_covariates,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/dataprocessing/encoders/encoders.py in _launch_encoder(self, target, past_covariates, future_covariates, n, encode_past, encode_future)
#    1034         # generate future covariates encodings
#    1035         if self.future_encoders and encode_future:
# -> 1036             future_covariates = self._encode_sequence(
#    1037                 encoders=self.future_encoders,
#    1038                 transformer=self.future_transformer,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/dataprocessing/encoders/encoders.py in _encode_sequence(self, encoders, transformer, target, covariates, covariates_type, n)
#    1080             )
#    1081             encoded = concatenate(
# -> 1082                 [
#    1083                     getattr(enc, encode_method)(
#    1084                         target=ts, covariates=covs, merge_covariates=False, n=n
#
# ~/anaconda3/lib/python3.9/site-packages/darts/dataprocessing/encoders/encoders.py in <listcomp>(.0)
#    1081             encoded = concatenate(
#    1082                 [
# -> 1083                     getattr(enc, encode_method)(
#    1084                         target=ts, covariates=covs, merge_covariates=False, n=n
#    1085                     )
#
# ~/anaconda3/lib/python3.9/site-packages/darts/dataprocessing/encoders/encoder_base.py in encode_train(self, target, covariates, merge_covariates, **kwargs)
#     597         # generate index and encodings
#     598         index, target_end = self.index_generator.generate_train_idx(target, covariates)
# --> 599         encoded = self._encode(index, target_end, target.dtype)
#     600
#     601         # optionally, merge encodings with original `covariates` series
#
# ~/anaconda3/lib/python3.9/site-packages/darts/dataprocessing/encoders/encoders.py in _encode(self, index, target_end, dtype)
#     347         """Applies cyclic encoding from `datetime_attribute_timeseries()` to `self.attribute` of `index`."""
#     348         super()._encode(index, target_end, dtype)
# --> 349         return datetime_attribute_timeseries(
#     350             index,
#     351             attribute=self.attribute,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/utils/timeseries_generation.py in datetime_attribute_timeseries(time_index, attribute, one_hot, cyclic, until, add_length, dtype, with_columns)
#     743
#     744     values_df.index = time_index
# --> 745     return TimeSeries.from_dataframe(values_df).astype(dtype)
#     746
#     747
#
# ~/anaconda3/lib/python3.9/site-packages/darts/timeseries.py in from_dataframe(cls, df, time_col, value_cols, fill_missing_dates, freq, fillna_value, static_covariates, hierarchy)
#     685         )
#     686
# --> 687         return cls.from_xarray(
#     688             xa=xa,
#     689             fill_missing_dates=fill_missing_dates,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/timeseries.py in from_xarray(cls, xa, fill_missing_dates, freq, fillna_value)
#     418             return cls(xa_)
#     419         else:
# --> 420             return cls(xa_.astype(np.float64))
#     421
#     422     @classmethod
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/core/common.py in astype(self, dtype, order, casting, subok, copy, keep_attrs)
#    1502         kwargs = {k: v for k, v in kwargs.items() if v is not None}
#    1503
# -> 1504         return apply_ufunc(
#    1505             duck_array_ops.astype,
#    1506             self,
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/core/computation.py in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, *args)
#    1163     # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1164     elif any(isinstance(a, DataArray) for a in args):
# -> 1165         return apply_dataarray_vfunc(
#    1166             variables_vfunc,
#    1167             *args,
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/core/computation.py in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     288
#     289     data_vars = [getattr(a, "variable", a) for a in args]
# --> 290     result_var = func(*data_vars)
#     291
#     292     if signature.num_outputs > 1:
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/core/computation.py in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     731             )
#     732
# --> 733     result_data = func(*input_data)
#     734
#     735     if signature.num_outputs == 1:
#
# ~/anaconda3/lib/python3.9/site-packages/xarray/core/duck_array_ops.py in astype(data, dtype, **kwargs)
#     186         kwargs.pop("casting")
#     187
# --> 188     return data.astype(dtype, **kwargs)
#     189
#     190
#
# TypeError: float() argument must be a string or a number, not 'datetime.time'

# %%
forecast = model.predict(len(val_price))
print(f'model {model} obtains MAPE: {mape(val, forecast):.2f}%')

# %% [markdown]
# ## Historical forecasts
# Forecasting using historical data.
#
# *Backtesting: General method for seeing how well a model would have done using historical data.

# %%
historical_fcast = model.historical_forecasts(
    series,
    start=0.80,
    forecast_horizon=168,
    stride=5,
    overlap_end=False,
    verbose=True
)

# %%
series.plot(label='data')
historical_fcast.plot(label='backtest 1 week ahead (AutoARIMA)')

# %%
print(f'MAPE = {mape(historical_fcast, series):.2f}%')

# %% [markdown]
# ## Backtest
# It repeatedly builds a training set from the beginning of series. It trains the current model on the training set, emits a forecast of length equal to forecast_horizon, and then moves the end of the training set forward by stride time steps.

# %%
raw_errors = model.backtest(
    series,
    start=0.80,
    forecast_horizon=168,
    stride=5,
    reduction=None,
    metric=mape,
    verbose=True
)

# %%
plot_hist(
    raw_errors,
    bins=np.arange(0, max(raw_errors), 1),
    title='individual backtest error scores (histogram)'
)

# %%
median_error = model.backtest(
    series,
    start=0.8,
    forecast_horizon=168,
    stride=5,
    reduction=np.median,
    metric=mape,
    verbose=True
)

# %%
print(f'Median error (MAPE) over all historical forecasts: {median_error:.2f}%')

# %%
average_error = model.backtest(
    series,
    start=0.8,
    forecast_horizon=168,
    stride=5,
    reduction=np.mean,
    metric=mape,
    verbose=True
)

# %%
print(f'Average error (MAPE) over all historical forecasts: {average_error:.2f}%')

# %% [markdown]
# ## Covariates

# %%
df.head(2)
# Out:
#              datetime  wind_speed  solar_radiation  temperature        date  \
# 0 2020-01-01 00:00:00         2.4                0         -0.1  2020-01-01
# 1 2020-01-01 01:00:00         2.4                0         -0.5  2020-01-01
#
#    day_of_week      time  month  nuclear_power  not_renewable    renewable  \
# 0            2  00:00:00      1     8088.21750    29512.74850  14541.30200
# 1            2  01:00:00      1     8081.15875    29178.66275  14949.45575
#
#    energy_price  total_energy_feeding
# 0         38.60           52142.26800
# 1         36.55           52209.27725

# %%
splitting_point = (int(len(series_price)*0.20))

# Set aside the second half of series as a validation series
train_price, val_price = series_price[:-splitting_point], series_price[-splitting_point:]

train_wind, val_wind = series_wind[:-splitting_point], series_wind[-splitting_point:]

# %%
train_price.plot()
val_price.plot()
train_wind.plot()
val_wind.plot()

# %%
scaler = Scaler()
train_price_scaled, train_wind_scaled = scaler.fit_transform([train_price, train_wind])

train_price_scaled.plot()
train_wind_scaled.plot()

# %%
encoders = {
    "datetime_attribute": {"future": ["time", "month", 'day_of_week']},
    "position": { "future": ["relative"]},
}

# %%
model = StatsForecastAutoARIMA()

# %%
model.fit(
    train_price_scaled
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11535/274346510.py in <module>
#       1 model.fit(
# ----> 2     train_price_scaled
#       3 )
#
# NameError: name 'train_price_scaled' is not defined
