# %% [markdown]
# ## LightGBM (Gradient Boosting Machine)
#
# - Multivariate
# - A gradient boosting ensemble method that is used by the train using AutoML tool and is based on decision trees. As with other decision tree-based methods, LightGBM can be used for both classification and regression. LightGBM is optimized for high performance with distributed systems.
# - Gradient Boosting Machine: a powerful ensemble machine learning algorithm that uses decision trees. Boosting is a general ensemble technique that involves sequentially adding models to the ensemble where subsequent models correct the performance of prior models.

# %%
from darts import TimeSeries
from darts.models import LightGBMModel
from darts.utils.statistics import plot_hist
from darts.metrics import mape
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../../data/prepared/df_energy_climate_2020.csv')

# %%
df = df.drop(['date', 'day_of_week', 'time', 'month'], axis=1)

# %%
# Create a TimeSeries, specifying the time and value columns
series = TimeSeries.from_dataframe(df, time_col="datetime")

splitting_point = (int(len(series)*0.20))

# Set aside the second half of series as a validation series
train, val = series[:-splitting_point], series[-splitting_point:]
# train, val = series.split_before(0.75)

# %%
train.plot()
val.plot()

# %%
model = LightGBMModel(lags=168)

# %%
model.fit(train)

forecast = model.predict(len(val))
print(f'model {model} obtains MAPE: {mape(val, forecast):.2f}%')
# Out:
# ValueError: The actual series must be strictly positive to compute the MAPE.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31391/3018346224.py in <module>
#       2
#       3 forecast = model.predict(len(val))
# ----> 4 print(f'model {model} obtains MAPE: {mape(val, forecast):.2f}%')
#
# ~/anaconda3/lib/python3.9/site-packages/darts/metrics/metrics.py in wrapper_multi_ts_support(*args, **kwargs)
#      85         )
#      86
# ---> 87         value_list = _parallel_apply(
#      88             iterator=iterator,
#      89             fn=func,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/utils/utils.py in _parallel_apply(iterator, fn, n_jobs, fn_args, fn_kwargs)
#     293     """
#     294
# --> 295     returned_data = Parallel(n_jobs=n_jobs)(
#     296         delayed(fn)(*sample, *fn_args, **fn_kwargs) for sample in iterator
#     297     )
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/anaconda3/lib/python3.9/site-packages/darts/metrics/metrics.py in wrapper_multivariate_support(*args, **kwargs)
#     131         for i in range(actual_series.width):
#     132             value_list.append(
# --> 133                 func(
#     134                     actual_series.univariate_component(i),
#     135                     pred_series.univariate_component(i),
#
# ~/anaconda3/lib/python3.9/site-packages/darts/metrics/metrics.py in mape(actual_series, pred_series, intersect, reduction, inter_reduction, n_jobs, verbose)
#     585         actual_series, pred_series, intersect, remove_nan_union=True
#     586     )
# --> 587     raise_if_not(
#     588         (y_true != 0).all(),
#     589         "The actual series must be strictly positive to compute the MAPE.",
#
# ~/anaconda3/lib/python3.9/site-packages/darts/logging.py in raise_if_not(condition, message, logger)
#      76     if not condition:
#      77         logger.error("ValueError: " + message)
# ---> 78         raise ValueError(message)
#      79
#      80
#
# ValueError: The actual series must be strictly positive to compute the MAPE.

# %% [markdown]
# ## Historical forecasts
# Forecasting using historical data.
#
# *Backtesting: General method for seeing how well a model would have done using historical data.

# %%
historical_fcast = model.historical_forecasts(
    series,
    start=0.8,
    forecast_horizon=168,
    stride=5,
    overlap_end=False,
    verbose=True
)
# Out:
#   0%|          | 0/319 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31391/668714510.py in <module>
# ----> 1 historical_fcast = model.historical_forecasts(
#       2     series,
#       3     start=0.8,
#       4     forecast_horizon=168,
#       5     stride=5,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/utils/utils.py in sanitized_method(self, *args, **kwargs)
#     177
#     178                 getattr(self, sanity_check_method)(*only_args.values(), **only_kwargs)
# --> 179             return method_to_sanitize(self, *only_args.values(), **only_kwargs)
#     180
#     181         return sanitized_method
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py in historical_forecasts(self, series, past_covariates, future_covariates, num_samples, train_length, start, forecast_horizon, stride, retrain, overlap_end, last_points_only, verbose)
#     863                     # avoid fitting the same model multiple times
#     864                     model = self.untrained_model()
# --> 865                     model._fit_wrapper(
#     866                         series=train_series,
#     867                         past_covariates=past_covariates_,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/forecasting_model.py in _fit_wrapper(self, series, past_covariates, future_covariates)
#    1815         future_covariates: Optional[TimeSeries],
#    1816     ):
# -> 1817         self.fit(
#    1818             series=series,
#    1819             past_covariates=past_covariates if self.supports_past_covariates else None,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/lgbm.py in fit(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, max_samples_per_ts, **kwargs)
#     191             return self
#     192
# --> 193         super().fit(
#     194             series=series,
#     195             past_covariates=past_covariates,
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py in fit(self, series, past_covariates, future_covariates, max_samples_per_ts, n_jobs_multioutput_wrapper, **kwargs)
#     480         )
#     481
# --> 482         self._fit_model(
#     483             series, past_covariates, future_covariates, max_samples_per_ts, **kwargs
#     484         )
#
# ~/anaconda3/lib/python3.9/site-packages/darts/models/forecasting/regression_model.py in _fit_model(self, target_series, past_covariates, future_covariates, max_samples_per_ts, **kwargs)
#     369         if len(training_labels.shape) == 2 and training_labels.shape[1] == 1:
#     370             training_labels = training_labels.ravel()
# --> 371         self.model.fit(training_samples, training_labels, **kwargs)
#     372
#     373     def fit(
#
# ~/anaconda3/lib/python3.9/site-packages/darts/utils/multioutput.py in fit(self, X, y, sample_weight, **fit_params)
#      82         else:
#      83             # without validation set
# ---> 84             self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      85                 delayed(_fit_estimator)(
#      86                     self.estimator, X, y[:, i], sample_weight, **fit_params_validated
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/multioutput.py in _fit_estimator(estimator, X, y, sample_weight, **fit_params)
#      42         estimator.fit(X, y, sample_weight=sample_weight, **fit_params)
#      43     else:
# ---> 44         estimator.fit(X, y, **fit_params)
#      45     return estimator
#      46
#
# ~/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     893             callbacks=None, init_model=None):
#     894         """Docstring is inherited from the LGBMModel."""
# --> 895         super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#     896                     eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     897                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#
# ~/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     746         callbacks.append(record_evaluation(evals_result))
#     747
# --> 748         self._Booster = train(
#     749             params=params,
#     750             train_set=train_set,
#
# ~/anaconda3/lib/python3.9/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     290                                     evaluation_result_list=None))
#     291
# --> 292         booster.update(fobj=fobj)
#     293
#     294         evaluation_result_list = []
#
# ~/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    3019             if self.__set_objective_to_none:
#    3020                 raise LightGBMError('Cannot update due to null objective function.')
# -> 3021             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    3022                 self.handle,
#    3023                 ctypes.byref(is_finished)))
#
# KeyboardInterrupt:

# %%
series.plot(label='data')
historical_fcast.plot(label='backtest 1 week ahead (exp smoothing)')
print(f'MAPE = {mape(historical_fcast, series):.2f}%')
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## Backtest
# It repeatedly builds a training set from the beginning of series. It trains the current model on the training set, emits a forecast of length equal to forecast_horizon, and then moves the end of the training set forward by stride time steps.

# %%
raw_errors = model.backtest(
    series,
    start=0.6,
    forecast_horizon=168,
    stride=5,
    reduction=None,
    metric=mape,
    verbose=True
)
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'

# %%
plot_hist(
    raw_errors,
    bins=np.arange(0, max(raw_errors), 1),
    title='individual backtest error scores (histogram)'
)
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'

# %%
median_error = model.backtest(
    series,
    start=0.6,
    forecast_horizon=168,
    stride=5,
    reduction=np.median,
    metric=mape,
    verbose=True
)
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'

# %%
print(f'Median error (MAPE) over all historical forecasts: {median_error:.2f}%')
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'

# %%
average_error = model.backtest(
    series,
    start=0.6,
    forecast_horizon=168,
    stride=5,
    reduction=np.mean,
    metric=mape,
    verbose=True
)
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'

# %%
print(f'Average error (MAPE) over all historical forecasts: {average_error:.2f}%')
# Out:
# Running cells with '/bin/python3.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.9 -m pip install ipykernel -U --user --force-reinstall'
